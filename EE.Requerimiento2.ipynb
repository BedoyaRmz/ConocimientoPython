# %% [markdown]
# **APRENDIZ:** *Dahiana Bedoya Ramirez*
#
# **FICHA:** *1751400*
#
# **FECHA DE INICIO DEL TALLER:** *20/11/2019*

# %% [markdown]
# Generar una tabla unificada que contenga las siguientes columnas:
#
# * Nombre de la estación.
# * Año.
# * Mes.
# * Dia.
# * Hora.
# * Velocidad media del viento para la correspodiente hora

# %%
import time
import datetime
#Funcion para leer y tranformar los 
def filetrans(file):
    estacion = open(file, 'r').readlines()
    transformacion = [row[0:-1]for row in estacion]
    transformacion = [row.split(';')for row in transformacion]
    transformacion = transformacion[1:]
    return transformacion

data = filetrans('files/06/Estacion1.csv')

# %%
#Agregar columna 'Nombre de la estación'
[[row[0].lower()]for row in data]
data = [[str('Estacion1')] + row   for row in data]

# %%
#cambiar formato de fecha
def changeFormat(s):
    return datetime.datetime.strptime(s, '%d/%m/%y').strftime('%Y/%m/%d')

# %%
#Retornar fecha en formato YY-MM-DD
data = [[row[0],changeFormat(row[1]),row[2],row[3],row[4]]for row in data]

# %%
#Funcion para obtener AÑO
def YEAR(s):
    return datetime.datetime.strptime(s, '%Y/%m/%d').strftime('%Y')

# %%
#Capturar AÑO en una columna
data = [[YEAR(row[1])] + row for row in data]

# %%
#ordenar datos para seguir trabajando
data = [[row[1],row[2],row[0],row[3],row[4],row[5],]for row in data]

# %%
#Función para obtener MES
def MONTH(s):
    return datetime.datetime.strptime(s, '%Y/%m/%d').month

# %%
#Capturar MES en una columna
data = [[MONTH(row[1])] + row for row in data]

# %%
#Ordenar datos para seguir trabajando
data = [[row[1],row[2],row[3],row[0],row[4],row[5],row[6]]for row in data]

# %%
#Función para obtener DIA
def DAYOFMONTH(s):
    return datetime.datetime.strptime(s, '%Y/%m/%d').strftime('%d')

# %%
#Capturar DIA en una columna
data = [[DAYOFMONTH(row[1])] + row for row in data]

# %%
#Ordenar datos
data = [[row[1],row[2],row[3],row[4],row[0],row[5],row[6],row[7]]for row in data]

# %%
#Función para obtener HORA
def HOUR(s):
    return datetime.datetime.strptime(s, '%H:%M:%S').strftime('%H')

# %%
#Capturar datos en una columna
data = [[HOUR(row[5])] + row for row in data]

# %%
#Ordenar datos para seguir trabajando
data = [[row[1],row[3],row[4],row[5],row[0],row[8]]for row in data]

# %%
data
# Out:
# [['Estacion1', '2005', 4, '16', '11', '6,3'],
#  ['Estacion1', '2005', 4, '16', '11', '5,1'],
#  ['Estacion1', '2005', 4, '16', '11', '6,3'],
#  ['Estacion1', '2005', 4, '16', '11', '6,1'],
#  ['Estacion1', '2005', 4, '16', '11', '4,1'],
#  ['Estacion1', '2005', 4, '16', '12', '5,5'],
#  ['Estacion1', '2005', 4, '16', '12', '5,4'],
#  ['Estacion1', '2005', 4, '16', '12', '5,5'],
#  ['Estacion1', '2005', 4, '16', '12', '4,6'],
#  ['Estacion1', '2005', 4, '16', '12', '6,7'],
#  ['Estacion1', '2005', 4, '16', '12', '5,0'],
#  ['Estacion1', '2005', 4, '16', '13', '5,5'],
#  ['Estacion1', '2005', 4, '16', '13', '5,8'],
#  ['Estacion1', '2005', 4, '16', '13', '5,3'],
#  ['Estacion1', '2005', 4, '16', '13', '4,2'],
#  ['Estacion1', '2005', 4, '16', '13', '3,8'],
#  ['Estacion1', '2005', 4, '16', '13', '4,6'],
#  ['Estacion1', '2005', 4, '16', '14', '4,5'],
#  ['Estacion1', '2005', 4, '16', '14', '3,7'],
#  ['Estacion1', '2005', 4, '16', '14', '2,8'],
#  ['Estacion1', '2005', 4, '16', '14', '3,4'],
#  ['Estacion1', '2005', 4, '16', '14', '4,6'],
#  ['Estacion1', '2005', 4, '16', '14', '3,0'],
#  ['Estacion1', '2005', 4, '16', '15', '2,5'],
#  ['Estacion1', '2005', 4, '16', '15', '3,1'],
#  ['Estacion1', '2005', 4, '16', '15', '2,6'],
#  ['Estacion1', '2005', 4, '16', '15', '4,1'],
#  ['Estacion1', '2005', 4, '16', '15', '4,2'],
#  ['Estacion1', '2005', 4, '16', '15', '4,3'],
#  ['Estacion1', '2005', 4, '16', '16', '3,3'],
#  ['Estacion1', '2005', 4, '16', '16', '4,3'],
#  ['Estacion1', '2005', 4, '16', '16', '4,3'],
#  ['Estacion1', '2005', 4, '16', '16', '3,9'],
#  ['Estacion1', '2005', 4, '16', '16', '2,3'],
#  ['Estacion1', '2005', 4, '16', '16', '4,1'],
#  ['Estacion1', '2005', 4, '16', '17', '4,6'],
#  ['Estacion1', '2005', 4, '16', '17', '5,6'],
#  ['Estacion1', '2005', 4, '16', '17', '5,1'],
#  ['Estacion1', '2005', 4, '16', '17', '6,1'],
#  ['Estacion1', '2005', 4, '16', '17', '4,3'],
#  ['Estacion1', '2005', 4, '16', '17', '3,3'],
#  ['Estacion1', '2005', 4, '16', '18', '4,1'],
#  ['Estacion1', '2005', 4, '16', '18', '4,3'],
#  ['Estacion1', '2005', 4, '16', '18', '4,1'],
#  ['Estacion1', '2005', 4, '16', '18', '4,5'],
#  ['Estacion1', '2005', 4, '16', '18', '5,4'],
#  ['Estacion1', '2005', 4, '16', '18', '6,2'],
#  ['Estacion1', '2005', 4, '16', '19', '4,3'],
#  ['Estacion1', '2005', 4, '16', '19', '4,0'],
#  ['Estacion1', '2005', 4, '16', '19', '2,5'],
#  ['Estacion1', '2005', 4, '16', '19', '4,8'],
#  ['Estacion1', '2005', 4, '16', '19', '5,7'],
#  ['Estacion1', '2005', 4, '16', '19', '4,8'],
#  ['Estacion1', '2005', 4, '16', '20', '4,9'],
#  ['Estacion1', '2005', 4, '16', '20', '2,8'],
#  ['Estacion1', '2005', 4, '16', '20', '2,8'],
#  ['Estacion1', '2005', 4, '16', '20', '2,2'],
#  ['Estacion1', '2005', 4, '16', '20', '2,0'],
#  ['Estacion1', '2005', 4, '16', '20', '1,4'],
#  ['Estacion1', '2005', 4, '16', '21', '1,8'],
#  ['Estacion1', '2005', 4, '16', '21', '3,2'],
#  ['Estacion1', '2005', 4, '16', '21', '2,7'],
#  ['Estacion1', '2005', 4, '16', '21', '3,8'],
#  ['Estacion1', '2005', 4, '16', '21', '3,9'],
#  ['Estacion1', '2005', 4, '16', '21', '3,8'],
#  ['Estacion1', '2005', 4, '16', '22', '4,0'],
#  ['Estacion1', '2005', 4, '16', '22', '4,5'],
#  ['Estacion1', '2005', 4, '16', '22', '2,6'],
#  ['Estacion1', '2005', 4, '16', '22', '3,8'],
#  ['Estacion1', '2005', 4, '16', '22', '2,1'],
#  ['Estacion1', '2005', 4, '16', '22', '2,9'],
#  ['Estacion1', '2005', 4, '16', '23', '11,6'],
#  ['Estacion1', '2005', 4, '16', '23', '10,5'],
#  ['Estacion1', '2005', 4, '16', '23', '6,1'],
#  ['Estacion1', '2005', 4, '16', '23', '6,7'],
#  ['Estacion1', '2005', 4, '16', '23', '9,9'],
#  ['Estacion1', '2005', 4, '16', '23', '10,7'],
#  ['Estacion1', '2005', 4, '17', '00', '8,1'],
#  ['Estacion1', '2005', 4, '17', '00', '9,0'],
#  ['Estacion1', '2005', 4, '17', '00', '9,3'],
#  ['Estacion1', '2005', 4, '17', '00', '8,8'],
#  ['Estacion1', '2005', 4, '17', '00', '5,5'],
#  ['Estacion1', '2005', 4, '17', '00', '4,6'],
#  ['Estacion1', '2005', 4, '17', '01', '3,4'],
#  ['Estacion1', '2005', 4, '17', '01', '3,1'],
#  ['Estacion1', '2005', 4, '17', '01', '3,8'],
#  ['Estacion1', '2005', 4, '17', '01', '1,9'],
#  ['Estacion1', '2005', 4, '17', '01', '2,3'],
#  ['Estacion1', '2005', 4, '17', '01', '3,9'],
#  ['Estacion1', '2005', 4, '17', '02', '3,8'],
#  ['Estacion1', '2005', 4, '17', '02', '3,0'],
#  ['Estacion1', '2005', 4, '17', '02', '2,5'],
#  ['Estacion1', '2005', 4, '17', '02', '4,1'],
#  ['Estacion1', '2005', 4, '17', '02', '2,7'],
#  ['Estacion1', '2005', 4, '17', '02', '2,9'],
#  ['Estacion1', '2005', 4, '17', '03', '4,5'],
#  ['Estacion1', '2005', 4, '17', '03', '2,6'],
#  ['Estacion1', '2005', 4, '17', '03', '1,6'],
#  ['Estacion1', '2005', 4, '17', '03', '3,0'],
#  ['Estacion1', '2005', 4, '17', '03', '1,6'],
#  ['Estacion1', '2005', 4, '17', '03', '1,0'],
#  ['Estacion1', '2005', 4, '17', '04', '2,1'],
#  ['Estacion1', '2005', 4, '17', '04', '2,2'],
#  ['Estacion1', '2005', 4, '17', '04', '1,2'],
#  ['Estacion1', '2005', 4, '17', '04', '0,6'],
#  ['Estacion1', '2005', 4, '17', '04', '0,9'],
#  ['Estacion1', '2005', 4, '17', '04', '0,5'],
#  ['Estacion1', '2005', 4, '17', '05', '0,6'],
#  ['Estacion1', '2005', 4, '17', '05', '0,8'],
#  ['Estacion1', '2005', 4, '17', '05', '0,6'],
#  ['Estacion1', '2005', 4, '17', '05', '0,5'],
#  ['Estacion1', '2005', 4, '17', '05', '0,7'],
#  ['Estacion1', '2005', 4, '17', '05', '0,3'],
#  ['Estacion1', '2005', 4, '17', '06', '0,9'],
#  ['Estacion1', '2005', 4, '17', '06', '0,9'],
#  ['Estacion1', '2005', 4, '17', '06', '0,9'],
#  ['Estacion1', '2005', 4, '17', '06', '1,1'],
#  ['Estacion1', '2005', 4, '17', '06', '0,8'],
#  ['Estacion1', '2005', 4, '17', '06', '0,8'],
#  ['Estacion1', '2005', 4, '17', '07', '1,2'],
#  ['Estacion1', '2005', 4, '17', '07', '1,8'],
#  ['Estacion1', '2005', 4, '17', '07', '3,2'],
#  ['Estacion1', '2005', 4, '17', '07', '3,3'],
#  ['Estacion1', '2005', 4, '17', '07', '2,2'],
#  ['Estacion1', '2005', 4, '17', '07', '3,1'],
#  ['Estacion1', '2005', 4, '17', '08', '3,4'],
#  ['Estacion1', '2005', 4, '17', '08', '3,7'],
#  ['Estacion1', '2005', 4, '17', '08', '2,4'],
#  ['Estacion1', '2005', 4, '17', '08', '2,3'],
#  ['Estacion1', '2005', 4, '17', '08', '2,3'],
#  ['Estacion1', '2005', 4, '17', '08', '2,0'],
#  ['Estacion1', '2005', 4, '17', '09', '2,3'],
#  ['Estacion1', '2005', 4, '17', '09', '3,4'],
#  ['Estacion1', '2005', 4, '17', '09', '5,2'],
#  ['Estacion1', '2005', 4, '17', '09', '5,9'],
#  ['Estacion1', '2005', 4, '17', '09', '8,8'],
#  ['Estacion1', '2005', 4, '17', '09', '6,1'],
#  ['Estacion1', '2005', 4, '17', '10', '4,1'],
#  ['Estacion1', '2005', 4, '17', '10', '4,2'],
#  ['Estacion1', '2005', 4, '17', '10', '3,7'],
#  ['Estacion1', '2005', 4, '17', '10', '4,1'],
#  ['Estacion1', '2005', 4, '17', '10', '2,9'],
#  ['Estacion1', '2005', 4, '17', '10', '6,3'],
#  ['Estacion1', '2005', 4, '17', '11', '4,5'],
#  ['Estacion1', '2005', 4, '17', '11', '5,1'],
#  ['Estacion1', '2005', 4, '17', '11', '5,4'],
#  ['Estacion1', '2005', 4, '17', '11', '4,1'],
#  ['Estacion1', '2005', 4, '17', '11', '4,8'],
#  ['Estacion1', '2005', 4, '17', '11', '5,3'],
#  ['Estacion1', '2005', 4, '17', '12', '4,6'],
#  ['Estacion1', '2005', 4, '17', '12', '4,7'],
#  ['Estacion1', '2005', 4, '17', '12', '4,6'],
#  ['Estacion1', '2005', 4, '17', '12', '2,6'],
#  ['Estacion1', '2005', 4, '17', '12', '2,5'],
#  ['Estacion1', '2005', 4, '17', '12', '3,9'],
#  ['Estacion1', '2005', 4, '17', '13', '1,9'],
#  ['Estacion1', '2005', 4, '17', '13', '1,7'],
#  ['Estacion1', '2005', 4, '17', '13', '4,9'],
#  ['Estacion1', '2005', 4, '17', '13', '3,9'],
#  ['Estacion1', '2005', 4, '17', '13', '3,7'],
#  ['Estacion1', '2005', 4, '17', '13', '4,0'],
#  ['Estacion1', '2005', 4, '17', '14', '2,5'],
#  ['Estacion1', '2005', 4, '17', '14', '2,9'],
#  ['Estacion1', '2005', 4, '17', '14', '4,4'],
#  ['Estacion1', '2005', 4, '17', '14', '3,7'],
#  ['Estacion1', '2005', 4, '17', '14', '3,4'],
#  ['Estacion1', '2005', 4, '17', '14', '3,0'],
#  ['Estacion1', '2005', 4, '17', '15', '2,8'],
#  ['Estacion1', '2005', 4, '17', '15', '3,4'],
#  ['Estacion1', '2005', 4, '17', '15', '4,2'],
#  ['Estacion1', '2005', 4, '17', '15', '4,3'],
#  ['Estacion1', '2005', 4, '17', '15', '4,3'],
#  ['Estacion1', '2005', 4, '17', '15', '4,2'],
#  ['Estacion1', '2005', 4, '17', '16', '2,9'],
#  ['Estacion1', '2005', 4, '17', '16', '1,3'],
#  ['Estacion1', '2005', 4, '17', '16', '2,1'],
#  ['Estacion1', '2005', 4, '17', '16', '2,0'],
#  ['Estacion1', '2005', 4, '17', '16', '2,7'],
#  ['Estacion1', '2005', 4, '17', '16', '1,5'],
#  ['Estacion1', '2005', 4, '17', '17', '2,0'],
#  ['Estacion1', '2005', 4, '17', '17', '1,0'],
#  ['Estacion1', '2005', 4, '17', '17', '0,9'],
#  ['Estacion1', '2005', 4, '17', '17', '2,0'],
#  ['Estacion1', '2005', 4, '17', '17', '2,1'],
#  ['Estacion1', '2005', 4, '17', '17', '2,4'],
#  ['Estacion1', '2005', 4, '17', '18', '2,2'],
#  ['Estacion1', '2005', 4, '17', '18', '2,2'],
#  ['Estacion1', '2005', 4, '17', '18', '2,0'],
#  ['Estacion1', '2005', 4, '17', '18', '2,5'],
#  ['Estacion1', '2005', 4, '17', '18', '1,8'],
#  ['Estacion1', '2005', 4, '17', '18', '1,7'],
#  ['Estacion1', '2005', 4, '17', '19', '1,1'],
#  ['Estacion1', '2005', 4, '17', '19', '0,9'],
#  ['Estacion1', '2005', 4, '17', '19', '0,8'],
#  ['Estacion1', '2005', 4, '17', '19', '1,1'],
#  ['Estacion1', '2005', 4, '17', '19', '1,2'],
#  ['Estacion1', '2005', 4, '17', '19', '0,9'],
#  ['Estacion1', '2005', 4, '17', '20', '1,6'],
#  ['Estacion1', '2005', 4, '17', '20', '2,3'],
#  ['Estacion1', '2005', 4, '17', '20', '2,5'],
#  ['Estacion1', '2005', 4, '17', '20', '2,3'],
#  ['Estacion1', '2005', 4, '17', '20', '1,2'],
#  ['Estacion1', '2005', 4, '17', '20', '1,4'],
#  ['Estacion1', '2005', 4, '17', '21', '2,1'],
#  ['Estacion1', '2005', 4, '17', '21', '2,9'],
#  ['Estacion1', '2005', 4, '17', '21', '2,5'],
#  ['Estacion1', '2005', 4, '17', '21', '2,1'],
#  ['Estacion1', '2005', 4, '17', '21', '2,3'],
#  ['Estacion1', '2005', 4, '17', '21', '2,2'],
#  ['Estacion1', '2005', 4, '17', '22', '2,4'],
#  ['Estacion1', '2005', 4, '17', '22', '2,6'],
#  ['Estacion1', '2005', 4, '17', '22', '1,9'],
#  ['Estacion1', '2005', 4, '17', '22', '1,8'],
#  ['Estacion1', '2005', 4, '17', '22', '2,0'],
#  ['Estacion1', '2005', 4, '17', '22', '2,0'],
#  ['Estacion1', '2005', 4, '17', '23', '1,6'],
#  ['Estacion1', '2005', 4, '17', '23', '1,6'],
#  ['Estacion1', '2005', 4, '17', '23', '0,5'],
#  ['Estacion1', '2005', 4, '17', '23', '0,8'],
#  ['Estacion1', '2005', 4, '17', '23', '0,9'],
#  ['Estacion1', '2005', 4, '17', '23', '0,8'],
#  ['Estacion1', '2005', 4, '18', '00', '1,3'],
#  ['Estacion1', '2005', 4, '18', '00', '1,3'],
#  ['Estacion1', '2005', 4, '18', '00', '1,4'],
#  ['Estacion1', '2005', 4, '18', '00', '1,3'],
#  ['Estacion1', '2005', 4, '18', '00', '1,4'],
#  ['Estacion1', '2005', 4, '18', '00', '1,6'],
#  ['Estacion1', '2005', 4, '18', '01', '0,9'],
#  ['Estacion1', '2005', 4, '18', '01', '1,2'],
#  ['Estacion1', '2005', 4, '18', '01', '0,6'],
#  ['Estacion1', '2005', 4, '18', '01', '1,0'],
#  ['Estacion1', '2005', 4, '18', '01', '1,2'],
#  ['Estacion1', '2005', 4, '18', '01', '1,0'],
#  ['Estacion1', '2005', 4, '18', '02', '1,6'],
#  ['Estacion1', '2005', 4, '18', '02', '1,0'],
#  ['Estacion1', '2005', 4, '18', '02', '1,1'],
#  ['Estacion1', '2005', 4, '18', '02', '2,3'],
#  ['Estacion1', '2005', 4, '18', '02', '2,4'],
#  ['Estacion1', '2005', 4, '18', '02', '1,8'],
#  ['Estacion1', '2005', 4, '18', '03', '0,8'],
#  ['Estacion1', '2005', 4, '18', '03', '1,0'],
#  ['Estacion1', '2005', 4, '18', '03', '1,3'],
#  ['Estacion1', '2005', 4, '18', '03', '1,1'],
#  ['Estacion1', '2005', 4, '18', '03', '1,3'],
#  ['Estacion1', '2005', 4, '18', '03', '2,5'],
#  ['Estacion1', '2005', 4, '18', '04', '4,9'],
#  ['Estacion1', '2005', 4, '18', '04', '3,9'],
#  ['Estacion1', '2005', 4, '18', '04', '4,2'],
#  ['Estacion1', '2005', 4, '18', '04', '3,6'],
#  ['Estacion1', '2005', 4, '18', '04', '4,2'],
#  ['Estacion1', '2005', 4, '18', '04', '4,0'],
#  ['Estacion1', '2005', 4, '18', '05', '5,3'],
#  ['Estacion1', '2005', 4, '18', '05', '4,6'],
#  ['Estacion1', '2005', 4, '18', '05', '3,5'],
#  ['Estacion1', '2005', 4, '18', '05', '3,8'],
#  ['Estacion1', '2005', 4, '18', '05', '3,8'],
#  ['Estacion1', '2005', 4, '18', '05', '3,9'],
#  ['Estacion1', '2005', 4, '18', '06', '2,8'],
#  ['Estacion1', '2005', 4, '18', '06', '3,7'],
#  ['Estacion1', '2005', 4, '18', '06', '5,1'],
#  ['Estacion1', '2005', 4, '18', '06', '4,6'],
#  ['Estacion1', '2005', 4, '18', '06', '4,0'],
#  ['Estacion1', '2005', 4, '18', '06', '5,1'],
#  ['Estacion1', '2005', 4, '18', '07', '4,5'],
#  ['Estacion1', '2005', 4, '18', '07', '5,4'],
#  ['Estacion1', '2005', 4, '18', '07', '5,3'],
#  ['Estacion1', '2005', 4, '18', '07', '7,2'],
#  ['Estacion1', '2005', 4, '18', '07', '8,4'],
#  ['Estacion1', '2005', 4, '18', '07', '8,5'],
#  ['Estacion1', '2005', 4, '18', '08', '8,1'],
#  ['Estacion1', '2005', 4, '18', '08', '8,5'],
#  ['Estacion1', '2005', 4, '18', '08', '8,4'],
#  ['Estacion1', '2005', 4, '18', '08', '7,3'],
#  ['Estacion1', '2005', 4, '18', '08', '7,3'],
#  ['Estacion1', '2005', 4, '18', '08', '8,5'],
#  ['Estacion1', '2005', 4, '18', '09', '7,9'],
#  ['Estacion1', '2005', 4, '18', '09', '8,1'],
#  ['Estacion1', '2005', 4, '18', '09', '5,5'],
#  ['Estacion1', '2005', 4, '18', '09', '4,4'],
#  ['Estacion1', '2005', 4, '18', '09', '3,5'],
#  ['Estacion1', '2005', 4, '18', '09', '3,5'],
#  ['Estacion1', '2005', 4, '18', '10', '2,1'],
#  ['Estacion1', '2005', 4, '18', '10', '2,8'],
#  ['Estacion1', '2005', 4, '18', '10', '3,5'],
#  ['Estacion1', '2005', 4, '18', '10', '2,7'],
#  ['Estacion1', '2005', 4, '18', '10', '3,7'],
#  ['Estacion1', '2005', 4, '18', '10', '4,1'],
#  ['Estacion1', '2005', 4, '18', '11', '4,4'],
#  ['Estacion1', '2005', 4, '18', '11', '4,0'],
#  ['Estacion1', '2005', 4, '18', '11', '2,2'],
#  ['Estacion1', '2005', 4, '18', '11', '2,4'],
#  ['Estacion1', '2005', 4, '18', '11', '2,0'],
#  ['Estacion1', '2005', 4, '18', '11', '3,7'],
#  ['Estacion1', '2005', 4, '18', '12', '3,1'],
#  ['Estacion1', '2005', 4, '18', '12', '3,8'],
#  ['Estacion1', '2005', 4, '18', '12', '2,1'],
#  ['Estacion1', '2005', 4, '18', '12', '3,0'],
#  ['Estacion1', '2005', 4, '18', '12', '2,6'],
#  ['Estacion1', '2005', 4, '18', '12', '4,1'],
#  ['Estacion1', '2005', 4, '18', '13', '4,8'],
#  ['Estacion1', '2005', 4, '18', '13', '3,5'],
#  ['Estacion1', '2005', 4, '18', '13', '4,7'],
#  ['Estacion1', '2005', 4, '18', '13', '7,5'],
#  ['Estacion1', '2005', 4, '18', '13', '7,6'],
#  ['Estacion1', '2005', 4, '18', '13', '5,8'],
#  ['Estacion1', '2005', 4, '18', '14', '7,3'],
#  ['Estacion1', '2005', 4, '18', '14', '4,7'],
#  ['Estacion1', '2005', 4, '18', '14', '7,7'],
#  ['Estacion1', '2005', 4, '18', '14', '7,1'],
#  ['Estacion1', '2005', 4, '18', '14', '5,8'],
#  ['Estacion1', '2005', 4, '18', '14', '4,2'],
#  ['Estacion1', '2005', 4, '18', '15', '4,7'],
#  ['Estacion1', '2005', 4, '18', '15', '5,4'],
#  ['Estacion1', '2005', 4, '18', '15', '4,7'],
#  ['Estacion1', '2005', 4, '18', '15', '6,9'],
#  ['Estacion1', '2005', 4, '18', '15', '8,2'],
#  ['Estacion1', '2005', 4, '18', '15', '9,1'],
#  ['Estacion1', '2005', 4, '18', '16', '7,8'],
#  ['Estacion1', '2005', 4, '18', '16', '7,6'],
#  ['Estacion1', '2005', 4, '18', '16', '7,0'],
#  ['Estacion1', '2005', 4, '18', '16', '6,1'],
#  ['Estacion1', '2005', 4, '18', '16', '6,6'],
#  ['Estacion1', '2005', 4, '18', '16', '7,8'],
#  ['Estacion1', '2005', 4, '18', '17', '7,6'],
#  ['Estacion1', '2005', 4, '18', '17', '8,9'],
#  ['Estacion1', '2005', 4, '18', '17', '6,9'],
#  ['Estacion1', '2005', 4, '18', '17', '7,1'],
#  ['Estacion1', '2005', 4, '18', '17', '6,2'],
#  ['Estacion1', '2005', 4, '18', '17', '6,2'],
#  ['Estacion1', '2005', 4, '18', '18', '6,7'],
#  ['Estacion1', '2005', 4, '18', '18', '7,8'],
#  ['Estacion1', '2005', 4, '18', '18', '7,4'],
#  ['Estacion1', '2005', 4, '18', '18', '7,8'],
#  ['Estacion1', '2005', 4, '18', '18', '6,7'],
#  ['Estacion1', '2005', 4, '18', '18', '7,4'],
#  ['Estacion1', '2005', 4, '18', '19', '6,9'],
#  ['Estacion1', '2005', 4, '18', '19', '7,4'],
#  ['Estacion1', '2005', 4, '18', '19', '4,8'],
#  ['Estacion1', '2005', 4, '18', '19', '3,9'],
#  ['Estacion1', '2005', 4, '18', '19', '5,2'],
#  ['Estacion1', '2005', 4, '18', '19', '3,3'],
#  ['Estacion1', '2005', 4, '18', '20', '3,3'],
#  ['Estacion1', '2005', 4, '18', '20', '4,8'],
#  ['Estacion1', '2005', 4, '18', '20', '3,2'],
#  ['Estacion1', '2005', 4, '18', '20', '2,1'],
#  ['Estacion1', '2005', 4, '18', '20', '2,5'],
#  ['Estacion1', '2005', 4, '18', '20', '1,8'],
#  ['Estacion1', '2005', 4, '18', '21', '1,4'],
#  ['Estacion1', '2005', 4, '18', '21', '1,3'],
#  ['Estacion1', '2005', 4, '18', '21', '2,2'],
#  ['Estacion1', '2005', 4, '18', '21', '1,7'],
#  ['Estacion1', '2005', 4, '18', '21', '1,0'],
#  ['Estacion1', '2005', 4, '18', '21', '1,0'],
#  ['Estacion1', '2005', 4, '18', '22', '0,3'],
#  ['Estacion1', '2005', 4, '18', '22', '0,5'],
#  ['Estacion1', '2005', 4, '18', '22', '0,7'],
#  ['Estacion1', '2005', 4, '18', '22', '0,8'],
#  ['Estacion1', '2005', 4, '18', '22', '1,3'],
#  ['Estacion1', '2005', 4, '18', '22', '0,7'],
#  ['Estacion1', '2005', 4, '18', '23', '0,3'],
#  ['Estacion1', '2005', 4, '18', '23', '1,2'],
#  ['Estacion1', '2005', 4, '18', '23', '1,7'],
#  ['Estacion1', '2005', 4, '18', '23', '2,0'],
#  ['Estacion1', '2005', 4, '18', '23', '2,1'],
#  ['Estacion1', '2005', 4, '18', '23', '1,1'],
#  ['Estacion1', '2005', 4, '19', '00', '3,8'],
#  ['Estacion1', '2005', 4, '19', '00', '4,0'],
#  ['Estacion1', '2005', 4, '19', '00', '4,2'],
#  ['Estacion1', '2005', 4, '19', '00', '1,7'],
#  ['Estacion1', '2005', 4, '19', '00', '2,7'],
#  ['Estacion1', '2005', 4, '19', '00', '3,2'],
#  ['Estacion1', '2005', 4, '19', '01', '3,9'],
#  ['Estacion1', '2005', 4, '19', '01', '3,2'],
#  ['Estacion1', '2005', 4, '19', '01', '4,5'],
#  ['Estacion1', '2005', 4, '19', '01', '2,9'],
#  ['Estacion1', '2005', 4, '19', '01', '1,4'],
#  ['Estacion1', '2005', 4, '19', '01', '2,8'],
#  ['Estacion1', '2005', 4, '19', '02', '2,3'],
#  ['Estacion1', '2005', 4, '19', '02', '2,0'],
#  ['Estacion1', '2005', 4, '19', '02', '1,9'],
#  ['Estacion1', '2005', 4, '19', '02', '0,6'],
#  ['Estacion1', '2005', 4, '19', '02', '1,1'],
#  ['Estacion1', '2005', 4, '19', '02', '1,5'],
#  ['Estacion1', '2005', 4, '19', '03', '2,0'],
#  ['Estacion1', '2005', 4, '19', '03', '1,7'],
#  ['Estacion1', '2005', 4, '19', '03', '1,6'],
#  ['Estacion1', '2005', 4, '19', '03', '2,4'],
#  ['Estacion1', '2005', 4, '19', '03', '2,3'],
#  ['Estacion1', '2005', 4, '19', '03', '2,1'],
#  ['Estacion1', '2005', 4, '19', '04', '2,0'],
#  ['Estacion1', '2005', 4, '19', '04', '1,2'],
#  ['Estacion1', '2005', 4, '19', '04', '0,6'],
#  ['Estacion1', '2005', 4, '19', '04', '0,6'],
#  ['Estacion1', '2005', 4, '19', '04', '1,0'],
#  ['Estacion1', '2005', 4, '19', '04', '0,4'],
#  ['Estacion1', '2005', 4, '19', '05', '0,9'],
#  ['Estacion1', '2005', 4, '19', '05', '0,4'],
#  ['Estacion1', '2005', 4, '19', '05', '1,4'],
#  ['Estacion1', '2005', 4, '19', '05', '1,2'],
#  ['Estacion1', '2005', 4, '19', '05', '1,9'],
#  ['Estacion1', '2005', 4, '19', '05', '2,4'],
#  ['Estacion1', '2005', 4, '19', '06', '2,3'],
#  ['Estacion1', '2005', 4, '19', '06', '2,2'],
#  ['Estacion1', '2005', 4, '19', '06', '2,8'],
#  ['Estacion1', '2005', 4, '19', '06', '2,8'],
#  ['Estacion1', '2005', 4, '19', '06', '2,8'],
#  ['Estacion1', '2005', 4, '19', '06', '2,8'],
#  ['Estacion1', '2005', 4, '19', '07', '1,5'],
#  ['Estacion1', '2005', 4, '19', '07', '1,3'],
#  ['Estacion1', '2005', 4, '19', '07', '2,4'],
#  ['Estacion1', '2005', 4, '19', '07', '2,4'],
#  ['Estacion1', '2005', 4, '19', '07', '2,0'],
#  ['Estacion1', '2005', 4, '19', '07', '2,4'],
#  ['Estacion1', '2005', 4, '19', '08', '6,1'],
#  ['Estacion1', '2005', 4, '19', '08', '5,9'],
#  ['Estacion1', '2005', 4, '19', '08', '5,7'],
#  ['Estacion1', '2005', 4, '19', '08', '2,8'],
#  ['Estacion1', '2005', 4, '19', '08', '1,9'],
#  ['Estacion1', '2005', 4, '19', '08', '1,3'],
#  ['Estacion1', '2005', 4, '19', '10', '6,7'],
#  ['Estacion1', '2005', 4, '19', '10', '5,2'],
#  ['Estacion1', '2005', 4, '19', '10', '4,6'],
#  ['Estacion1', '2005', 4, '19', '10', '6,4'],
#  ['Estacion1', '2005', 4, '19', '10', '5,9'],
#  ['Estacion1', '2005', 4, '19', '10', '8,2'],
#  ['Estacion1', '2005', 4, '19', '11', '8,1'],
#  ['Estacion1', '2005', 4, '19', '11', '7,3'],
#  ['Estacion1', '2005', 4, '19', '11', '6,0'],
#  ['Estacion1', '2005', 4, '19', '11', '7,9'],
#  ['Estacion1', '2005', 4, '19', '11', '8,0'],
#  ['Estacion1', '2005', 4, '19', '11', '7,3'],
#  ['Estacion1', '2005', 4, '19', '12', '8,3'],
#  ['Estacion1', '2005', 4, '19', '12', '7,8'],
#  ['Estacion1', '2005', 4, '19', '12', '7,9'],
#  ['Estacion1', '2005', 4, '19', '12', '7,5'],
#  ['Estacion1', '2005', 4, '19', '12', '6,3'],
#  ['Estacion1', '2005', 4, '19', '12', '6,8'],
#  ['Estacion1', '2005', 4, '19', '13', '6,6'],
#  ['Estacion1', '2005', 4, '19', '13', '5,7'],
#  ['Estacion1', '2005', 4, '19', '13', '6,8'],
#  ['Estacion1', '2005', 4, '19', '13', '5,4'],
#  ['Estacion1', '2005', 4, '19', '13', '6,4'],
#  ['Estacion1', '2005', 4, '19', '13', '6,9'],
#  ['Estacion1', '2005', 4, '19', '14', '6,5'],
#  ['Estacion1', '2005', 4, '19', '14', '6,0'],
#  ['Estacion1', '2005', 4, '19', '14', '4,1'],
#  ['Estacion1', '2005', 4, '19', '14', '2,9'],
#  ['Estacion1', '2005', 4, '19', '14', '2,9'],
#  ['Estacion1', '2005', 4, '19', '14', '6,1'],
#  ['Estacion1', '2005', 4, '19', '15', '4,7'],
#  ['Estacion1', '2005', 4, '19', '15', '5,9'],
#  ['Estacion1', '2005', 4, '19', '15', '5,4'],
#  ['Estacion1', '2005', 4, '19', '15', '7,2'],
#  ['Estacion1', '2005', 4, '19', '15', '8,9'],
#  ['Estacion1', '2005', 4, '19', '15', '7,9'],
#  ['Estacion1', '2005', 4, '19', '17', '6,1'],
#  ['Estacion1', '2005', 4, '19', '17', '6,2'],
#  ['Estacion1', '2005', 4, '19', '17', '5,3'],
#  ['Estacion1', '2005', 4, '19', '17', '5,0'],
#  ['Estacion1', '2005', 4, '19', '17', '5,1'],
#  ['Estacion1', '2005', 4, '19', '17', '4,9'],
#  ['Estacion1', '2005', 4, '19', '18', '5,5'],
#  ['Estacion1', '2005', 4, '19', '18', '4,5'],
#  ['Estacion1', '2005', 4, '19', '18', '4,6'],
#  ['Estacion1', '2005', 4, '19', '18', '4,3'],
#  ['Estacion1', '2005', 4, '19', '18', '5,4'],
#  ['Estacion1', '2005', 4, '19', '18', '3,6'],
#  ['Estacion1', '2005', 4, '19', '19', '2,5'],
#  ['Estacion1', '2005', 4, '19', '19', '1,9'],
#  ['Estacion1', '2005', 4, '19', '19', '3,5'],
#  ['Estacion1', '2005', 4, '19', '19', '3,5'],
#  ['Estacion1', '2005', 4, '19', '19', '4,2'],
#  ['Estacion1', '2005', 4, '19', '19', '3,1'],
#  ['Estacion1', '2005', 4, '19', '20', '3,9'],
#  ['Estacion1', '2005', 4, '19', '20', '3,7'],
#  ['Estacion1', '2005', 4, '19', '20', '2,7'],
#  ['Estacion1', '2005', 4, '19', '20', '3,4'],
#  ['Estacion1', '2005', 4, '19', '20', '3,8'],
#  ['Estacion1', '2005', 4, '19', '20', '3,7'],
#  ['Estacion1', '2005', 4, '19', '21', '3,4'],
#  ['Estacion1', '2005', 4, '19', '21', '5,4'],
#  ['Estacion1', '2005', 4, '19', '21', '5,1'],
#  ['Estacion1', '2005', 4, '19', '21', '4,9'],
#  ['Estacion1', '2005', 4, '19', '21', '5,6'],
#  ['Estacion1', '2005', 4, '19', '21', '2,7'],
#  ['Estacion1', '2005', 4, '19', '22', '3,4'],
#  ['Estacion1', '2005', 4, '19', '22', '4,1'],
#  ['Estacion1', '2005', 4, '19', '22', '4,7'],
#  ['Estacion1', '2005', 4, '19', '22', '4,6'],
#  ['Estacion1', '2005', 4, '19', '22', '3,5'],
#  ['Estacion1', '2005', 4, '19', '22', '3,1'],
#  ['Estacion1', '2005', 4, '19', '23', '2,6'],
#  ['Estacion1', '2005', 4, '19', '23', '2,3'],
#  ['Estacion1', '2005', 4, '19', '23', '1,4'],
#  ['Estacion1', '2005', 4, '19', '23', '1,5'],
#  ['Estacion1', '2005', 4, '19', '23', '1,3'],
#  ['Estacion1', '2005', 4, '19', '23', '0,6'],
#  ['Estacion1', '2005', 4, '20', '00', '0,6'],
#  ['Estacion1', '2005', 4, '20', '00', '0,8'],
#  ['Estacion1', '2005', 4, '20', '00', '1,6'],
#  ['Estacion1', '2005', 4, '20', '00', '1,5'],
#  ['Estacion1', '2005', 4, '20', '00', '1,4'],
#  ['Estacion1', '2005', 4, '20', '00', '3,3'],
#  ['Estacion1', '2005', 4, '20', '01', '3,6'],
#  ['Estacion1', '2005', 4, '20', '01', '3,7'],
#  ['Estacion1', '2005', 4, '20', '01', '3,7'],
#  ['Estacion1', '2005', 4, '20', '01', '2,7'],
#  ['Estacion1', '2005', 4, '20', '01', '1,7'],
#  ['Estacion1', '2005', 4, '20', '01', '2,1'],
#  ['Estacion1', '2005', 4, '20', '02', '3,6'],
#  ['Estacion1', '2005', 4, '20', '02', '2,9'],
#  ['Estacion1', '2005', 4, '20', '02', '1,3'],
#  ['Estacion1', '2005', 4, '20', '02', '1,8'],
#  ['Estacion1', '2005', 4, '20', '02', '2,1'],
#  ['Estacion1', '2005', 4, '20', '02', '3,1'],
#  ['Estacion1', '2005', 4, '20', '03', '3,3'],
#  ['Estacion1', '2005', 4, '20', '03', '3,2'],
#  ['Estacion1', '2005', 4, '20', '03', '2,4'],
#  ['Estacion1', '2005', 4, '20', '03', '2,4'],
#  ['Estacion1', '2005', 4, '20', '03', '2,8'],
#  ['Estacion1', '2005', 4, '20', '03', '3,0'],
#  ['Estacion1', '2005', 4, '20', '04', '2,5'],
#  ['Estacion1', '2005', 4, '20', '04', '2,7'],
#  ['Estacion1', '2005', 4, '20', '04', '3,0'],
#  ['Estacion1', '2005', 4, '20', '04', '2,3'],
#  ['Estacion1', '2005', 4, '20', '04', '2,1'],
#  ['Estacion1', '2005', 4, '20', '04', '1,9'],
#  ['Estacion1', '2005', 4, '20', '05', '2,2'],
#  ['Estacion1', '2005', 4, '20', '05', '3,0'],
#  ['Estacion1', '2005', 4, '20', '05', '2,9'],
#  ['Estacion1', '2005', 4, '20', '05', '2,5'],
#  ['Estacion1', '2005', 4, '20', '05', '2,5'],
#  ['Estacion1', '2005', 4, '20', '05', '1,0'],
#  ['Estacion1', '2005', 4, '20', '06', '1,2'],
#  ['Estacion1', '2005', 4, '20', '06', '1,3'],
#  ['Estacion1', '2005', 4, '20', '06', '2,9'],
#  ['Estacion1', '2005', 4, '20', '06', '2,7'],
#  ['Estacion1', '2005', 4, '20', '06', '2,7'],
#  ['Estacion1', '2005', 4, '20', '06', '2,1'],
#  ['Estacion1', '2005', 4, '20', '07', '2,4'],
#  ['Estacion1', '2005', 4, '20', '07', '2,8'],
#  ['Estacion1', '2005', 4, '20', '07', '2,6'],
#  ['Estacion1', '2005', 4, '20', '07', '2,0'],
#  ['Estacion1', '2005', 4, '20', '07', '1,7'],
#  ['Estacion1', '2005', 4, '20', '07', '1,4'],
#  ['Estacion1', '2005', 4, '20', '08', '2,9'],
#  ['Estacion1', '2005', 4, '20', '08', '2,8'],
#  ['Estacion1', '2005', 4, '20', '08', '1,8'],
#  ['Estacion1', '2005', 4, '20', '08', '3,2'],
#  ['Estacion1', '2005', 4, '20', '08', '1,0'],
#  ['Estacion1', '2005', 4, '20', '08', '1,1'],
#  ['Estacion1', '2005', 4, '20', '09', '1,5'],
#  ['Estacion1', '2005', 4, '20', '09', '2,6'],
#  ['Estacion1', '2005', 4, '20', '09', '1,9'],
#  ['Estacion1', '2005', 4, '20', '09', '2,7'],
#  ['Estacion1', '2005', 4, '20', '09', '3,1'],
#  ['Estacion1', '2005', 4, '20', '09', '3,9'],
#  ['Estacion1', '2005', 4, '20', '10', '3,5'],
#  ['Estacion1', '2005', 4, '20', '10', '5,3'],
#  ['Estacion1', '2005', 4, '20', '10', '3,9'],
#  ['Estacion1', '2005', 4, '20', '10', '2,9'],
#  ['Estacion1', '2005', 4, '20', '10', '2,4'],
#  ['Estacion1', '2005', 4, '20', '10', '5,8'],
#  ['Estacion1', '2005', 4, '20', '11', '5,0'],
#  ['Estacion1', '2005', 4, '20', '11', '4,0'],
#  ['Estacion1', '2005', 4, '20', '11', '3,0'],
#  ['Estacion1', '2005', 4, '20', '11', '2,9'],
#  ['Estacion1', '2005', 4, '20', '11', '3,3'],
#  ['Estacion1', '2005', 4, '20', '11', '4,0'],
#  ['Estacion1', '2005', 4, '20', '12', '3,4'],
#  ['Estacion1', '2005', 4, '20', '12', '2,8'],
#  ['Estacion1', '2005', 4, '20', '12', '4,9'],
#  ['Estacion1', '2005', 4, '20', '12', '5,2'],
#  ['Estacion1', '2005', 4, '20', '12', '4,7'],
#  ['Estacion1', '2005', 4, '20', '12', '5,8'],
#  ['Estacion1', '2005', 4, '20', '13', '3,6'],
#  ['Estacion1', '2005', 4, '20', '13', '5,8'],
#  ['Estacion1', '2005', 4, '20', '13', '5,9'],
#  ['Estacion1', '2005', 4, '20', '13', '3,8'],
#  ['Estacion1', '2005', 4, '20', '13', '1,5'],
#  ['Estacion1', '2005', 4, '20', '13', '2,5'],
#  ['Estacion1', '2005', 4, '20', '14', '1,3'],
#  ['Estacion1', '2005', 4, '20', '14', '4,8'],
#  ['Estacion1', '2005', 4, '20', '14', '4,9'],
#  ['Estacion1', '2005', 4, '20', '14', '3,2'],
#  ['Estacion1', '2005', 4, '20', '14', '1,5'],
#  ['Estacion1', '2005', 4, '20', '14', '3,1'],
#  ['Estacion1', '2005', 4, '20', '15', '1,9'],
#  ['Estacion1', '2005', 4, '20', '15', '1,9'],
#  ['Estacion1', '2005', 4, '20', '15', '2,2'],
#  ['Estacion1', '2005', 4, '20', '15', '3,0'],
#  ['Estacion1', '2005', 4, '20', '15', '1,4'],
#  ['Estacion1', '2005', 4, '20', '15', '1,0'],
#  ['Estacion1', '2005', 4, '20', '16', '3,3'],
#  ['Estacion1', '2005', 4, '20', '16', '2,8'],
#  ['Estacion1', '2005', 4, '20', '16', '3,8'],
#  ['Estacion1', '2005', 4, '20', '16', '4,0'],
#  ['Estacion1', '2005', 4, '20', '16', '3,8'],
#  ['Estacion1', '2005', 4, '20', '16', '3,7'],
#  ['Estacion1', '2005', 4, '20', '17', '3,0'],
#  ['Estacion1', '2005', 4, '20', '17', '2,0'],
#  ['Estacion1', '2005', 4, '20', '17', '0,6'],
#  ['Estacion1', '2005', 4, '20', '17', '0,4'],
#  ['Estacion1', '2005', 4, '20', '17', '0,4'],
#  ['Estacion1', '2005', 4, '20', '17', '1,1'],
#  ['Estacion1', '2005', 4, '20', '18', '1,2'],
#  ['Estacion1', '2005', 4, '20', '18', '1,6'],
#  ['Estacion1', '2005', 4, '20', '18', '1,7'],
#  ['Estacion1', '2005', 4, '20', '18', '1,2'],
#  ['Estacion1', '2005', 4, '20', '18', '0,8'],
#  ['Estacion1', '2005', 4, '20', '18', '0,8'],
#  ['Estacion1', '2005', 4, '20', '19', '0,7'],
#  ['Estacion1', '2005', 4, '20', '19', '1,2'],
#  ['Estacion1', '2005', 4, '20', '19', '0,6'],
#  ['Estacion1', '2005', 4, '20', '19', '0,9'],
#  ['Estacion1', '2005', 4, '20', '19', '1,7'],
#  ['Estacion1', '2005', 4, '20', '19', '2,6'],
#  ['Estacion1', '2005', 4, '20', '20', '1,4'],
#  ['Estacion1', '2005', 4, '20', '20', '0,7'],
#  ['Estacion1', '2005', 4, '20', '20', '1,2'],
#  ['Estacion1', '2005', 4, '20', '20', '1,5'],
#  ['Estacion1', '2005', 4, '20', '20', '0,5'],
#  ['Estacion1', '2005', 4, '20', '20', '0,7'],
#  ['Estacion1', '2005', 4, '20', '21', '1,5'],
#  ['Estacion1', '2005', 4, '20', '21', '1,4'],
#  ['Estacion1', '2005', 4, '20', '21', '1,1'],
#  ['Estacion1', '2005', 4, '20', '21', '1,3'],
#  ['Estacion1', '2005', 4, '20', '21', '1,5'],
#  ['Estacion1', '2005', 4, '20', '21', '1,5'],
#  ['Estacion1', '2005', 4, '20', '22', '2,9'],
#  ['Estacion1', '2005', 4, '20', '22', '1,9'],
#  ['Estacion1', '2005', 4, '20', '22', '1,4'],
#  ['Estacion1', '2005', 4, '20', '22', '1,8'],
#  ['Estacion1', '2005', 4, '20', '22', '2,5'],
#  ['Estacion1', '2005', 4, '20', '22', '2,5'],
#  ['Estacion1', '2005', 4, '20', '23', '2,3'],
#  ['Estacion1', '2005', 4, '20', '23', '2,9'],
#  ['Estacion1', '2005', 4, '20', '23', '2,1'],
#  ['Estacion1', '2005', 4, '20', '23', '1,3'],
#  ['Estacion1', '2005', 4, '20', '23', '1,0'],
#  ['Estacion1', '2005', 4, '20', '23', '1,2'],
#  ['Estacion1', '2005', 4, '21', '00', '0,9'],
#  ['Estacion1', '2005', 4, '21', '00', '0,7'],
#  ['Estacion1', '2005', 4, '21', '00', '0,9'],
#  ['Estacion1', '2005', 4, '21', '00', '1,2'],
#  ['Estacion1', '2005', 4, '21', '00', '0,9'],
#  ['Estacion1', '2005', 4, '21', '00', '0,8'],
#  ['Estacion1', '2005', 4, '21', '01', '1,6'],
#  ['Estacion1', '2005', 4, '21', '01', '1,6'],
#  ['Estacion1', '2005', 4, '21', '01', '1,1'],
#  ['Estacion1', '2005', 4, '21', '01', '1,5'],
#  ['Estacion1', '2005', 4, '21', '01', '1,6'],
#  ['Estacion1', '2005', 4, '21', '01', '1,7'],
#  ['Estacion1', '2005', 4, '21', '02', '1,3'],
#  ['Estacion1', '2005', 4, '21', '02', '1,7'],
#  ['Estacion1', '2005', 4, '21', '02', '1,8'],
#  ['Estacion1', '2005', 4, '21', '02', '1,5'],
#  ['Estacion1', '2005', 4, '21', '02', '1,5'],
#  ['Estacion1', '2005', 4, '21', '02', '1,0'],
#  ['Estacion1', '2005', 4, '21', '03', '1,2'],
#  ['Estacion1', '2005', 4, '21', '03', '1,0'],
#  ['Estacion1', '2005', 4, '21', '03', '2,8'],
#  ['Estacion1', '2005', 4, '21', '03', '2,3'],
#  ['Estacion1', '2005', 4, '21', '03', '2,3'],
#  ['Estacion1', '2005', 4, '21', '03', '2,6'],
#  ['Estacion1', '2005', 4, '21', '04', '1,6'],
#  ['Estacion1', '2005', 4, '21', '04', '1,5'],
#  ['Estacion1', '2005', 4, '21', '04', '0,8'],
#  ['Estacion1', '2005', 4, '21', '04', '1,4'],
#  ['Estacion1', '2005', 4, '21', '04', '0,8'],
#  ['Estacion1', '2005', 4, '21', '04', '1,4'],
#  ['Estacion1', '2005', 4, '21', '05', '1,4'],
#  ['Estacion1', '2005', 4, '21', '05', '1,4'],
#  ['Estacion1', '2005', 4, '21', '05', '0,4'],
#  ['Estacion1', '2005', 4, '21', '05', '0,6'],
#  ['Estacion1', '2005', 4, '21', '05', '1,3'],
#  ['Estacion1', '2005', 4, '21', '05', '1,4'],
#  ['Estacion1', '2005', 4, '21', '06', '1,5'],
#  ['Estacion1', '2005', 4, '21', '06', '1,1'],
#  ['Estacion1', '2005', 4, '21', '06', '2,4'],
#  ['Estacion1', '2005', 4, '21', '06', '1,9'],
#  ['Estacion1', '2005', 4, '21', '06', '1,4'],
#  ['Estacion1', '2005', 4, '21', '06', '0,8'],
#  ['Estacion1', '2005', 4, '21', '07', '0,7'],
#  ['Estacion1', '2005', 4, '21', '07', '0,9'],
#  ['Estacion1', '2005', 4, '21', '07', '0,6'],
#  ['Estacion1', '2005', 4, '21', '07', '0,8'],
#  ['Estacion1', '2005', 4, '21', '07', '2,7'],
#  ['Estacion1', '2005', 4, '21', '07', '2,6'],
#  ['Estacion1', '2005', 4, '21', '08', '4,0'],
#  ['Estacion1', '2005', 4, '21', '08', '2,8'],
#  ['Estacion1', '2005', 4, '21', '08', '2,0'],
#  ['Estacion1', '2005', 4, '21', '08', '2,2'],
#  ['Estacion1', '2005', 4, '21', '08', '2,0'],
#  ['Estacion1', '2005', 4, '21', '08', '2,2'],
#  ['Estacion1', '2005', 4, '21', '09', '1,3'],
#  ['Estacion1', '2005', 4, '21', '09', '1,9'],
#  ['Estacion1', '2005', 4, '21', '09', '1,7'],
#  ['Estacion1', '2005', 4, '21', '09', '2,8'],
#  ['Estacion1', '2005', 4, '21', '09', '3,7'],
#  ['Estacion1', '2005', 4, '21', '09', '6,5'],
#  ['Estacion1', '2005', 4, '21', '11', '5,3'],
#  ['Estacion1', '2005', 4, '21', '11', '5,0'],
#  ['Estacion1', '2005', 4, '21', '11', '6,6'],
#  ['Estacion1', '2005', 4, '21', '11', '5,6'],
#  ['Estacion1', '2005', 4, '21', '11', '6,1'],
#  ['Estacion1', '2005', 4, '21', '11', '5,5'],
#  ['Estacion1', '2005', 4, '21', '13', '4,7'],
#  ['Estacion1', '2005', 4, '21', '13', '7,2'],
#  ['Estacion1', '2005', 4, '21', '13', '6,9'],
#  ['Estacion1', '2005', 4, '21', '13', '5,4'],
#  ['Estacion1', '2005', 4, '21', '13', '4,7'],
#  ['Estacion1', '2005', 4, '21', '13', '3,4'],
#  ['Estacion1', '2005', 4, '21', '14', '2,6'],
#  ['Estacion1', '2005', 4, '21', '14', '1,5'],
#  ['Estacion1', '2005', 4, '21', '14', '2,0'],
#  ['Estacion1', '2005', 4, '21', '14', '2,2'],
#  ['Estacion1', '2005', 4, '21', '14', '1,2'],
#  ['Estacion1', '2005', 4, '21', '14', '1,5'],
#  ['Estacion1', '2005', 4, '21', '15', '1,8'],
#  ['Estacion1', '2005', 4, '21', '15', '1,8'],
#  ['Estacion1', '2005', 4, '21', '15', '2,2'],
#  ['Estacion1', '2005', 4, '21', '15', '2,1'],
#  ['Estacion1', '2005', 4, '21', '15', '2,0'],
#  ['Estacion1', '2005', 4, '21', '15', '2,0'],
#  ['Estacion1', '2005', 4, '21', '16', '1,9'],
#  ['Estacion1', '2005', 4, '21', '16', '2,2'],
#  ['Estacion1', '2005', 4, '21', '16', '4,4'],
#  ['Estacion1', '2005', 4, '21', '16', '4,2'],
#  ['Estacion1', '2005', 4, '21', '16', '3,1'],
#  ['Estacion1', '2005', 4, '21', '16', '3,3'],
#  ['Estacion1', '2005', 4, '21', '17', '1,8'],
#  ['Estacion1', '2005', 4, '21', '17', '2,6'],
#  ['Estacion1', '2005', 4, '21', '17', '2,0'],
#  ['Estacion1', '2005', 4, '21', '17', '1,5'],
#  ['Estacion1', '2005', 4, '21', '17', '0,7'],
#  ['Estacion1', '2005', 4, '21', '17', '1,4'],
#  ['Estacion1', '2005', 4, '21', '18', '2,3'],
#  ['Estacion1', '2005', 4, '21', '18', '1,4'],
#  ['Estacion1', '2005', 4, '21', '18', '0,8'],
#  ['Estacion1', '2005', 4, '21', '18', '1,5'],
#  ['Estacion1', '2005', 4, '21', '18', '1,2'],
#  ['Estacion1', '2005', 4, '21', '18', '0,9'],
#  ['Estacion1', '2005', 4, '21', '19', '1,1'],
#  ['Estacion1', '2005', 4, '21', '19', '1,0'],
#  ['Estacion1', '2005', 4, '21', '19', '1,1'],
#  ['Estacion1', '2005', 4, '21', '19', '0,8'],
#  ['Estacion1', '2005', 4, '21', '19', '1,2'],
#  ['Estacion1', '2005', 4, '21', '19', '1,4'],
#  ['Estacion1', '2005', 4, '21', '20', '1,3'],
#  ['Estacion1', '2005', 4, '21', '20', '1,4'],
#  ['Estacion1', '2005', 4, '21', '20', '0,8'],
#  ['Estacion1', '2005', 4, '21', '20', '0,8'],
#  ['Estacion1', '2005', 4, '21', '20', '1,3'],
#  ['Estacion1', '2005', 4, '21', '20', '0,9'],
#  ['Estacion1', '2005', 4, '21', '21', '1,2'],
#  ['Estacion1', '2005', 4, '21', '21', '1,5'],
#  ['Estacion1', '2005', 4, '21', '21', '2,5'],
#  ['Estacion1', '2005', 4, '21', '21', '2,8'],
#  ['Estacion1', '2005', 4, '21', '21', '2,1'],
#  ['Estacion1', '2005', 4, '21', '21', '3,5'],
#  ['Estacion1', '2005', 4, '21', '22', '5,2'],
#  ['Estacion1', '2005', 4, '21', '22', '5,5'],
#  ['Estacion1', '2005', 4, '21', '22', '5,4'],
#  ['Estacion1', '2005', 4, '21', '22', '5,2'],
#  ['Estacion1', '2005', 4, '21', '22', '6,2'],
#  ['Estacion1', '2005', 4, '21', '22', '5,5'],
#  ['Estacion1', '2005', 4, '21', '23', '4,6'],
#  ['Estacion1', '2005', 4, '21', '23', '3,8'],
#  ['Estacion1', '2005', 4, '21', '23', '1,6'],
#  ['Estacion1', '2005', 4, '21', '23', '3,8'],
#  ['Estacion1', '2005', 4, '21', '23', '1,4'],
#  ['Estacion1', '2005', 4, '21', '23', '1,8'],
#  ['Estacion1', '2005', 4, '22', '01', '2,2'],
#  ['Estacion1', '2005', 4, '22', '01', '2,3'],
#  ['Estacion1', '2005', 4, '22', '01', '2,5'],
#  ['Estacion1', '2005', 4, '22', '01', '2,0'],
#  ['Estacion1', '2005', 4, '22', '01', '2,3'],
#  ['Estacion1', '2005', 4, '22', '01', '1,8'],
#  ['Estacion1', '2005', 4, '22', '02', '1,4'],
#  ['Estacion1', '2005', 4, '22', '02', '1,9'],
#  ['Estacion1', '2005', 4, '22', '02', '2,5'],
#  ['Estacion1', '2005', 4, '22', '02', '3,2'],
#  ['Estacion1', '2005', 4, '22', '02', '1,5'],
#  ['Estacion1', '2005', 4, '22', '02', '1,3'],
#  ['Estacion1', '2005', 4, '22', '03', '1,4'],
#  ['Estacion1', '2005', 4, '22', '03', '0,9'],
#  ['Estacion1', '2005', 4, '22', '03', '1,3'],
#  ['Estacion1', '2005', 4, '22', '03', '1,1'],
#  ['Estacion1', '2005', 4, '22', '03', '1,2'],
#  ['Estacion1', '2005', 4, '22', '03', '0,8'],
#  ['Estacion1', '2005', 4, '22', '04', '0,9'],
#  ['Estacion1', '2005', 4, '22', '04', '1,4'],
#  ['Estacion1', '2005', 4, '22', '04', '2,0'],
#  ['Estacion1', '2005', 4, '22', '04', '3,0'],
#  ['Estacion1', '2005', 4, '22', '04', '2,3'],
#  ['Estacion1', '2005', 4, '22', '04', '1,5'],
#  ['Estacion1', '2005', 4, '22', '05', '1,7'],
#  ['Estacion1', '2005', 4, '22', '05', '0,9'],
#  ['Estacion1', '2005', 4, '22', '05', '1,6'],
#  ['Estacion1', '2005', 4, '22', '05', '1,4'],
#  ['Estacion1', '2005', 4, '22', '05', '1,7'],
#  ['Estacion1', '2005', 4, '22', '05', '1,0'],
#  ['Estacion1', '2005', 4, '22', '06', '1,2'],
#  ['Estacion1', '2005', 4, '22', '06', '1,5'],
#  ['Estacion1', '2005', 4, '22', '06', '1,1'],
#  ['Estacion1', '2005', 4, '22', '06', '1,1'],
#  ['Estacion1', '2005', 4, '22', '06', '1,1'],
#  ['Estacion1', '2005', 4, '22', '06', '0,6'],
#  ['Estacion1', '2005', 4, '22', '07', '0,6'],
#  ['Estacion1', '2005', 4, '22', '07', '0,8'],
#  ['Estacion1', '2005', 4, '22', '07', '0,9'],
#  ['Estacion1', '2005', 4, '22', '07', '1,5'],
#  ['Estacion1', '2005', 4, '22', '07', '1,5'],
#  ['Estacion1', '2005', 4, '22', '07', '1,1'],
#  ['Estacion1', '2005', 4, '22', '09', '2,2'],
#  ['Estacion1', '2005', 4, '22', '09', '2,2'],
#  ['Estacion1', '2005', 4, '22', '09', '3,1'],
#  ['Estacion1', '2005', 4, '22', '09', '2,7'],
#  ['Estacion1', '2005', 4, '22', '09', '2,6'],
#  ['Estacion1', '2005', 4, '22', '09', '3,3'],
#  ['Estacion1', '2005', 4, '22', '10', '3,7'],
#  ['Estacion1', '2005', 4, '22', '10', '3,2'],
#  ['Estacion1', '2005', 4, '22', '10', '2,0'],
#  ['Estacion1', '2005', 4, '22', '10', '1,7'],
#  ['Estacion1', '2005', 4, '22', '10', '2,4'],
#  ['Estacion1', '2005', 4, '22', '10', '2,0'],
#  ['Estacion1', '2005', 4, '22', '12', '3,7'],
#  ['Estacion1', '2005', 4, '22', '12', '7,1'],
#  ['Estacion1', '2005', 4, '22', '12', '5,6'],
#  ['Estacion1', '2005', 4, '22', '12', '4,3'],
#  ['Estacion1', '2005', 4, '22', '12', '4,4'],
#  ['Estacion1', '2005', 4, '22', '12', '5,3'],
#  ['Estacion1', '2005', 4, '22', '13', '4,7'],
#  ['Estacion1', '2005', 4, '22', '13', '4,1'],
#  ['Estacion1', '2005', 4, '22', '13', '2,7'],
#  ['Estacion1', '2005', 4, '22', '13', '2,7'],
#  ['Estacion1', '2005', 4, '22', '13', '3,2'],
#  ['Estacion1', '2005', 4, '22', '13', '3,3'],
#  ['Estacion1', '2005', 4, '22', '14', '3,2'],
#  ['Estacion1', '2005', 4, '22', '14', '2,2'],
#  ['Estacion1', '2005', 4, '22', '14', '1,9'],
#  ['Estacion1', '2005', 4, '22', '14', '2,3'],
#  ['Estacion1', '2005', 4, '22', '14', '2,2'],
#  ['Estacion1', '2005', 4, '22', '14', '1,9'],
#  ['Estacion1', '2005', 4, '22', '15', '1,4'],
#  ['Estacion1', '2005', 4, '22', '15', '2,4'],
#  ['Estacion1', '2005', 4, '22', '15', '1,9'],
#  ['Estacion1', '2005', 4, '22', '15', '1,6'],
#  ['Estacion1', '2005', 4, '22', '15', '1,6'],
#  ['Estacion1', '2005', 4, '22', '15', '1,4'],
#  ['Estacion1', '2005', 4, '22', '16', '2,1'],
#  ['Estacion1', '2005', 4, '22', '16', '2,8'],
#  ['Estacion1', '2005', 4, '22', '16', '3,3'],
#  ['Estacion1', '2005', 4, '22', '16', '3,3'],
#  ['Estacion1', '2005', 4, '22', '16', '2,9'],
#  ['Estacion1', '2005', 4, '22', '16', '2,7'],
#  ['Estacion1', '2005', 4, '22', '17', '0,8'],
#  ['Estacion1', '2005', 4, '22', '17', '1,3'],
#  ['Estacion1', '2005', 4, '22', '17', '2,6'],
#  ['Estacion1', '2005', 4, '22', '17', '2,0'],
#  ['Estacion1', '2005', 4, '22', '17', '2,3'],
#  ['Estacion1', '2005', 4, '22', '17', '1,6'],
#  ['Estacion1', '2005', 4, '22', '18', '1,5'],
#  ['Estacion1', '2005', 4, '22', '18', '1,5'],
#  ['Estacion1', '2005', 4, '22', '18', '1,0'],
#  ['Estacion1', '2005', 4, '22', '18', '1,0'],
#  ['Estacion1', '2005', 4, '22', '18', '1,0'],
#  ['Estacion1', '2005', 4, '22', '18', '1,8'],
#  ['Estacion1', '2005', 4, '22', '19', '1,6'],
#  ['Estacion1', '2005', 4, '22', '19', '1,4'],
#  ['Estacion1', '2005', 4, '22', '19', '0,8'],
#  ['Estacion1', '2005', 4, '22', '19', '0,5'],
#  ['Estacion1', '2005', 4, '22', '19', '2,2'],
#  ['Estacion1', '2005', 4, '22', '19', '1,6'],
#  ['Estacion1', '2005', 4, '22', '20', '0,8'],
#  ['Estacion1', '2005', 4, '22', '20', '0,9'],
#  ['Estacion1', '2005', 4, '22', '20', '1,6'],
#  ['Estacion1', '2005', 4, '22', '20', '0,5'],
#  ['Estacion1', '2005', 4, '22', '20', '0,7'],
#  ['Estacion1', '2005', 4, '22', '20', '0,9'],
#  ['Estacion1', '2005', 4, '22', '21', '0,6'],
#  ['Estacion1', '2005', 4, '22', '21', '1,3'],
#  ['Estacion1', '2005', 4, '22', '21', '2,3'],
#  ['Estacion1', '2005', 4, '22', '21', '1,4'],
#  ['Estacion1', '2005', 4, '22', '21', '1,1'],
#  ['Estacion1', '2005', 4, '22', '21', '1,6'],
#  ['Estacion1', '2005', 4, '22', '22', '1,6'],
#  ['Estacion1', '2005', 4, '22', '22', '2,2'],
#  ['Estacion1', '2005', 4, '22', '22', '1,9'],
#  ['Estacion1', '2005', 4, '22', '22', '1,1'],
#  ['Estacion1', '2005', 4, '22', '22', '0,9'],
#  ['Estacion1', '2005', 4, '22', '22', '1,0'],
#  ['Estacion1', '2005', 4, '22', '23', '1,5'],
#  ['Estacion1', '2005', 4, '22', '23', '2,5'],
#  ['Estacion1', '2005', 4, '22', '23', '1,3'],
#  ['Estacion1', '2005', 4, '22', '23', '2,0'],
#  ['Estacion1', '2005', 4, '22', '23', '1,8'],
#  ['Estacion1', '2005', 4, '22', '23', '1,8'],
#  ['Estacion1', '2005', 4, '23', '00', '1,4'],
#  ['Estacion1', '2005', 4, '23', '00', '0,7'],
#  ['Estacion1', '2005', 4, '23', '00', '0,7'],
#  ['Estacion1', '2005', 4, '23', '00', '1,0'],
#  ['Estacion1', '2005', 4, '23', '00', '0,9'],
#  ['Estacion1', '2005', 4, '23', '00', '1,5'],
#  ['Estacion1', '2005', 4, '23', '01', '1,6'],
#  ['Estacion1', '2005', 4, '23', '01', '1,7'],
#  ['Estacion1', '2005', 4, '23', '01', '1,9'],
#  ['Estacion1', '2005', 4, '23', '01', '1,8'],
#  ['Estacion1', '2005', 4, '23', '01', '2,1'],
#  ['Estacion1', '2005', 4, '23', '01', '1,6'],
#  ['Estacion1', '2005', 4, '23', '02', '0,5'],
#  ['Estacion1', '2005', 4, '23', '02', '0,5'],
#  ['Estacion1', '2005', 4, '23', '02', '1,5'],
#  ['Estacion1', '2005', 4, '23', '02', '1,7'],
#  ['Estacion1', '2005', 4, '23', '02', '2,1'],
#  ['Estacion1', '2005', 4, '23', '02', '1,1'],
#  ['Estacion1', '2005', 4, '23', '03', '2,1'],
#  ['Estacion1', '2005', 4, '23', '03', '1,9'],
#  ['Estacion1', '2005', 4, '23', '03', '1,0'],
#  ['Estacion1', '2005', 4, '23', '03', '1,8'],
#  ['Estacion1', '2005', 4, '23', '03', '2,5'],
#  ['Estacion1', '2005', 4, '23', '03', '2,0'],
#  ['Estacion1', '2005', 4, '23', '04', '1,3'],
#  ['Estacion1', '2005', 4, '23', '04', '0,4'],
#  ['Estacion1', '2005', 4, '23', '04', '0,8'],
#  ['Estacion1', '2005', 4, '23', '04', '0,7'],
#  ['Estacion1', '2005', 4, '23', '04', '1,0'],
#  ['Estacion1', '2005', 4, '23', '04', '0,8'],
#  ['Estacion1', '2005', 4, '23', '05', '1,3'],
#  ['Estacion1', '2005', 4, '23', '05', '0,7'],
#  ['Estacion1', '2005', 4, '23', '05', '0,4'],
#  ['Estacion1', '2005', 4, '23', '05', '0,3'],
#  ['Estacion1', '2005', 4, '23', '05', '0,2'],
#  ['Estacion1', '2005', 4, '23', '05', '0,5'],
#  ['Estacion1', '2005', 4, '23', '06', '0,9'],
#  ['Estacion1', '2005', 4, '23', '06', '0,6'],
#  ['Estacion1', '2005', 4, '23', '06', '0,5'],
#  ['Estacion1', '2005', 4, '23', '06', '1,3'],
#  ['Estacion1', '2005', 4, '23', '06', '1,4'],
#  ['Estacion1', '2005', 4, '23', '06', '1,7'],
#  ['Estacion1', '2005', 4, '23', '07', '1,2'],
#  ['Estacion1', '2005', 4, '23', '07', '0,9'],
#  ['Estacion1', '2005', 4, '23', '07', '0,7'],
#  ['Estacion1', '2005', 4, '23', '07', '0,4'],
#  ['Estacion1', '2005', 4, '23', '07', '0,4'],
#  ['Estacion1', '2005', 4, '23', '07', '0,8'],
#  ['Estacion1', '2005', 4, '23', '08', '0,9'],
#  ['Estacion1', '2005', 4, '23', '08', '0,7'],
#  ['Estacion1', '2005', 4, '23', '08', '0,7'],
#  ['Estacion1', '2005', 4, '23', '08', '1,3'],
#  ['Estacion1', '2005', 4, '23', '08', '1,5'],
#  ['Estacion1', '2005', 4, '23', '08', '1,1'],
#  ['Estacion1', '2005', 4, '23', '09', '1,3'],
#  ['Estacion1', '2005', 4, '23', '09', '1,8'],
#  ['Estacion1', '2005', 4, '23', '09', '1,3'],
#  ['Estacion1', '2005', 4, '23', '09', '2,2'],
#  ['Estacion1', '2005', 4, '23', '09', '2,6'],
#  ['Estacion1', '2005', 4, '23', '09', '2,6'],
#  ['Estacion1', '2005', 4, '23', '10', '1,9'],
#  ['Estacion1', '2005', 4, '23', '10', '2,5'],
#  ['Estacion1', '2005', 4, '23', '10', '2,1'],
#  ['Estacion1', '2005', 4, '23', '10', '1,5'],
#  ['Estacion1', '2005', 4, '23', '10', '1,2'],
#  ['Estacion1', '2005', 4, '23', '10', '1,1'],
#  ['Estacion1', '2005', 4, '23', '11', '1,4'],
#  ['Estacion1', '2005', 4, '23', '11', '1,8'],
#  ['Estacion1', '2005', 4, '23', '11', '1,4'],
#  ['Estacion1', '2005', 4, '23', '11', '1,5'],
#  ['Estacion1', '2005', 4, '23', '11', '1,5'],
#  ['Estacion1', '2005', 4, '23', '11', '1,4'],
#  ['Estacion1', '2005', 4, '23', '12', '1,4'],
#  ['Estacion1', '2005', 4, '23', '12', '1,6'],
#  ['Estacion1', '2005', 4, '23', '12', '1,9'],
#  ['Estacion1', '2005', 4, '23', '12', '3,7'],
#  ['Estacion1', '2005', 4, '23', '12', '4,3'],
#  ['Estacion1', '2005', 4, '23', '12', '3,4'],
#  ['Estacion1', '2005', 4, '23', '13', '3,4'],
#  ['Estacion1', '2005', 4, '23', '13', '2,2'],
#  ['Estacion1', '2005', 4, '23', '13', '1,9'],
#  ['Estacion1', '2005', 4, '23', '13', '1,6'],
#  ['Estacion1', '2005', 4, '23', '13', '1,5'],
#  ['Estacion1', '2005', 4, '23', '13', '1,5'],
#  ['Estacion1', '2005', 4, '23', '14', '1,3'],
#  ['Estacion1', '2005', 4, '23', '14', '1,1'],
#  ['Estacion1', '2005', 4, '23', '14', '1,1'],
#  ['Estacion1', '2005', 4, '23', '14', '1,4'],
#  ['Estacion1', '2005', 4, '23', '14', '2,9'],
#  ['Estacion1', '2005', 4, '23', '14', '2,8'],
#  ['Estacion1', '2005', 4, '23', '15', '3,4'],
#  ['Estacion1', '2005', 4, '23', '15', '5,7'],
#  ['Estacion1', '2005', 4, '23', '15', '3,6'],
#  ['Estacion1', '2005', 4, '23', '15', '3,5'],
#  ['Estacion1', '2005', 4, '23', '15', '2,7'],
#  ['Estacion1', '2005', 4, '23', '15', '2,8'],
#  ['Estacion1', '2005', 4, '23', '16', '2,3'],
#  ['Estacion1', '2005', 4, '23', '16', '1,8'],
#  ['Estacion1', '2005', 4, '23', '16', '1,6'],
#  ['Estacion1', '2005', 4, '23', '16', '1,3'],
#  ['Estacion1', '2005', 4, '23', '16', '0,9'],
#  ...]
